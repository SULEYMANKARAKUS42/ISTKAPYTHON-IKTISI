# %%
print("Merhaba, İGÜ-ISTKA ") # prınt ekrana cıktı veren koddur
# Out:
# Merhaba, İGÜ-ISTKA

# %% [markdown]
# pyhthon proglamlama dilinde print komutu ekrandan kullanıcıya bilgi veren bir koddur
# 06.08,2024 veri yapıları algoritmalar dersi

# %%
import sys #import python proglama dilinde yazılıma kütüphane eklemeye yarayan  kod bloğudur
print(sys.version)
# Out:
# 3.10.12 (main, Jul 29 2024, 16:56:48) [GCC 11.4.0]

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
os.chdir('/content/drive/MY Drive/VERIYAPILARI_ISTKA')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-13-98059be084b5> in <cell line: 2>()
#       1 import os
# ----> 2 os.chdir('/content/drive/MY Drive/VERIYAPILARI_ISTKA')
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/drive/MY Drive/VERIYAPILARI_ISTKA'
